# %% [markdown]
# # Veschiedenes
#
# #### Begriffe
# * Statistik
# * Stochastik
# * Wahrscheinlichkeitsrechnung
# * Kombinatorik
# * Inferenz
# * Regression
# * Gausssche Prozesse
# * Gaussche Felder (gaussian random fields)
# * Kovarianz
# * Standardabweichung
# * Mittelwert
# * Median
# * Wahrscheinlichkeitsdichtefunktion (probability density function)
